# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('/Users/kaiyang/Desktop/First assignment/WV7_Data.csv')
df.head()
# Out:
# /var/folders/rr/q2hphpp53sg6tswwk64tz_tw0000gn/T/ipykernel_8677/903761344.py:1: DtypeWarning: Columns (345,347,349,574,575,576) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/kaiyang/Desktop/First assignment/WV7_Data.csv')
#               version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 0  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 1  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 2  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 3  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 4  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
#
#    B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 0         20             AND        232         AND     20070001  ...
# 1         20             AND        232         AND     20070002  ...
# ...

# %%
# Selection of multiples rows with conditions
mydata1 = df[df['B_COUNTRY']==344]
mydata1.head()
# Out:
#                   version                        doi  A_WAVE  A_YEAR  A_STUDY  \
# 30656  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 30657  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 30658  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 30659  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
# 30660  5-0-0 (2022-12-23)  doi.org/10.14281/18241.20       7    2018        2
#
#        B_COUNTRY B_COUNTRY_ALPHA  C_COW_NUM C_COW_ALPHA  D_INTERVIEW  ...  \
# 30656        344             HKG        714         HKG    344070001  ...
# 30657        344             HKG        714         HKG    344070002  ...
# 30658        344             HKG        714         HKG    344070003  ...
# 30659        344             HKG        714         HKG    344070004  ...
# 30660        344             HKG        714         HKG    344070005  ...
#
# ...

# %%
# Selecting multiple columns/variables measuring public confidence in political institutions
# Q71: confidence in government; Q72: confidence in political parties; Q73: confidence in parliament; Q112: perception of corruption; Q121: attitude to immigrants; Q164: Faith in God   

mydata2 = mydata1[['Q71','Q72','Q73','Q112','Q121','Q164']]
mydata2.head()
# Out:
#        Q71  Q72  Q73  Q112  Q121  Q164
# 30656    2    3    3     6     4     5
# 30657    4    4    4     8     2     1
# 30658    2    3    3     5     3     1
# 30659    4    4    4     6     3     2
# 30660    2    2    2     5     3     6

# %%
mydata2.describe()
# Out:
#                Q71          Q72          Q73         Q112         Q121  \
# count  2075.000000  2075.000000  2075.000000  2075.000000  2075.000000
# mean      2.488193     2.871807     2.749880     5.389398     2.737349
# std       0.864621     0.883225     0.844515     2.104705     0.856045
# min      -2.000000    -2.000000    -2.000000    -2.000000    -2.000000
# 25%       2.000000     3.000000     2.000000     4.000000     2.000000
# 50%       2.000000     3.000000     3.000000     5.000000     3.000000
# 75%       3.000000     3.000000     3.000000     7.000000     3.000000
# max       4.000000     4.000000     4.000000    10.000000     5.000000
#
#               Q164
# count  2075.000000
# mean      4.884819
# std       2.911378
# min      -2.000000
# 25%       2.000000
# 50%       5.000000
# 75%       7.000000
# max      10.000000

# %%
# draw a boxplot on public perception of corruption (variable name = Q12) in Hong Kong

import matplotlib.pyplot as plt

fig = plt.figure(figsize =(10, 8))

plt.boxplot(mydata2["Q112"]);

plt.show()

# %%
cormat = mydata2.corr()
round(cormat, 2)
# Out:
#        Q71   Q72   Q73  Q112  Q121  Q164
# Q71   1.00  0.47  0.55  0.32 -0.19 -0.02
# Q72   0.47  1.00  0.67  0.16 -0.04 -0.07
# Q73   0.55  0.67  1.00  0.22 -0.09 -0.09
# Q112  0.32  0.16  0.22  1.00 -0.15  0.06
# Q121 -0.19 -0.04 -0.09 -0.15  1.00  0.02
# Q164 -0.02 -0.07 -0.09  0.06  0.02  1.00

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cormat , cmap='RdBu_r', annot=True);
plt.show()
