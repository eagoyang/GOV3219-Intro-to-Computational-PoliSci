# %% [markdown]
# ### Step 1: Import Necessary Libraries

# %%
pip install wordcloud nltk textblob
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.6-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: nltk in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (3.8.1)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from wordcloud) (10.2.0)
# Requirement already satisfied: matplotlib in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: click in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: colorama in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\kaiyang\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.6-cp311-cp311-win_amd64.whl (306 kB)
#    ---------------------------------------- 0.0/306.1 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/306.1 kB 660.6 kB/s eta 0:00:01
#    ------------- -------------------------- 102.4/306.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 306.1/306.1 kB 2.7 MB/s eta 0:00:00
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    --------------------------------------- 625.0/625.0 kB 19.8 MB/s eta 0:00:00
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------  1.5/1.6 MB 49.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: nltk, wordcloud, textblob
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.8.1
#     Uninstalling nltk-3.8.1:
#       Successfully uninstalled nltk-3.8.1
# Successfully installed nltk-3.9.4 textblob-0.20.0 wordcloud-1.9.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import string
import re

# %% [markdown]
# ### Step 2: Load the CSV File

# %%
with open("C:/Users/kaiyang/Desktop/SCMP_articles/SCMP_Iran.txt", "r", encoding="utf-8") as f:
    article_text = f.read()

df = pd.DataFrame({'doc_id': ['SCMP_article'], 'text': [article_text]})

df.head()
# Out:
#          doc_id                                               text
# 0  SCMP_article  US moves to block Iranian ports as Tehran thre...

# %% [markdown]
# ### Step 3: Preprocess the Text

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

# Initialize Lemmatizer
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove ALL punctuation (including smart quotes)
    
    tokens = word_tokenize(text)  # Tokenize words
    
    tokens = [word for word in tokens if word not in stopwords.words('english')]  # Remove stopwords
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Apply lemmatization
    return " ".join(lemmatized_tokens)

# Apply cleaning function to all titles
df['cleaned_text'] = df['text'].astype(str).apply(clean_text)

# Check cleaned text
print(df[['text', 'cleaned_text']].head())

df.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kaiyang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\kaiyang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\kaiyang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kaiyang\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                                                 text  \
# 0  US moves to block Iranian ports as Tehran thre...
#
#                                         cleaned_text
# 0  u move block iranian port tehran threatens ret...
#          doc_id                                               text  \
# 0  SCMP_article  US moves to block Iranian ports as Tehran thre...
#
#                                         cleaned_text
# 0  u move block iranian port tehran threatens ret...

# %% [markdown]
# ### Step 4: Generate a Word Cloud

# %%
# Combine all titles into a single string
text = " ".join(df['cleaned_text'])

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title("Word Cloud of News Text")
plt.show()

# %% [markdown]
# ### Step 5: Sentiment Analysis

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity  # Returns value between -1 (negative) and 1 (positive)

# Apply sentiment function
df['sentiment'] = df['cleaned_text'].apply(get_sentiment)

# Check results
print(df[['text', 'sentiment']].head())
# Out:
#                                                 text  sentiment
# 0  US moves to block Iranian ports as Tehran thre...   0.054068

# %% [markdown]
# ### Step 6: Visualize Sentiment Distribution

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['sentiment'], bins=10, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(x=0, color='red', linestyle='--', linewidth=2, label='Neutral (0)')
plt.xlabel('Sentiment Score')
plt.ylabel('Number of Articles')
plt.title('Distribution of Sentiment Scores Across Articles')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(12, 6))

# Sort by sentiment score (optional - makes trends easier to see)
df_sorted = df.sort_values('sentiment', ascending=False)

# Create bars with colors based on sentiment
colors = ['green' if x > 0 else 'red' if x < 0 else 'gray' for x in df_sorted['sentiment']]
bars = plt.bar(df_sorted['doc_id'], df_sorted['sentiment'], color=colors, edgecolor='black')

# Add a horizontal line at zero (neutral)
plt.axhline(y=0, color='black', linestyle='-', linewidth=0.8)

# Add value labels on top of each bar
for bar, score in zip(bars, df_sorted['sentiment']):
    plt.text(bar.get_x() + bar.get_width()/2, 
             bar.get_height() + (0.02 if score >= 0 else -0.05),
             f'{score:.3f}', 
             ha='center', 
             va='bottom' if score >= 0 else 'top',
             fontsize=9)

# Customize the plot
plt.xlabel('Article Name', fontsize=12)
plt.ylabel('Sentiment Score', fontsize=12)
plt.title('Sentiment Scores for Each News Article', fontsize=14, fontweight='bold')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add a legend
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='green', label='Positive'),
                   Patch(facecolor='gray', label='Neutral'),
                   Patch(facecolor='red', label='Negative')]
plt.legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 7: Save Processed Data (Optional)

# %%
# df.to_csv("/Users/kaiyang/Desktop/processed_news_data.csv", index=False)

# %% [markdown]
# # The End, thank you!
