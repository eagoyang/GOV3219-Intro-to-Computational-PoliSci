# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4) (2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL
url = "https://debatepolitics.com/forums/2024-us-presidential-election.227/"

# Set headers to mimic a browser request (avoid bot detection)
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %% [markdown]
# ### Scraping a Single Page

# %%
# Send a GET request
response = requests.get(url, headers=headers)

# Extract Titles
titles = [title.get_text(strip=True) for title in soup.select(".structItem-title a")]

# Extract URLs (prepend with site domain)
urls = ["https://debatepolitics.com" + link["href"] for link in soup.select(".structItem-title a")]

# Extract Replies
replies = [reply.get_text(strip=True) for reply in soup.select(".structItem-cell.structItem-cell--meta dl:nth-of-type(1) dd")]

# Extract Views
views = [view.get_text(strip=True) for view in soup.select(".structItem-cell.structItem-cell--meta dl:nth-of-type(2) dd")]

# Print Results
for i in range(len(titles)):
    print(f"Title: {titles[i]}")
    print(f"URL: {urls[i]}")
    print(f"Replies: {replies[i]}")
    print(f"Views: {views[i]}")
    print("-" * 50)
# Out:
# Title: For some Latinos, ‘prosperity gospel’ led them to Trump
# URL: https://debatepolitics.com/threads/for-some-latinos-%E2%80%98prosperity-gospel%E2%80%99-led-them-to-trump.557926/
# Replies: 48
# Views: 2K
# --------------------------------------------------
# Title: How the GOP is on Self-Destruct
# URL: https://debatepolitics.com/threads/how-the-gop-is-on-self-destruct.557954/
# Replies: 2
# Views: 174
# --------------------------------------------------
# Title: Kamala's Been On A Drinking Binge Since Losing
# URL: https://debatepolitics.com/threads/kamalas-been-on-a-drinking-binge-since-losing.556181/
# Replies: 187
# Views: 2K
# --------------------------------------------------
# Title: The Victory
# URL: https://debatepolitics.com/threads/the-victory.554963/
# Replies: 182
# Views: 2K
# --------------------------------------------------
# Title: It Must Really Suck For You People
# URL: https://debatepolitics.com/threads/it-must-really-suck-for-you-people.557448/
# Replies: 290
# Views: 2K
# --------------------------------------------------
# Title: Manifestly Unfit
# URL: https://debatepolitics.com/threads/manifestly-unfit.557682/
# Replies: 129
# Views: 1K
# --------------------------------------------------
# Title: Poll: 65% of Canadians agree with Trump's wish to make them the 51st state
# URL: https://debatepolitics.com/threads/poll-65-of-canadians-agree-with-trumps-wish-to-make-them-the-51st-state.557506/
# Replies: 56
# Views: 775
# --------------------------------------------------
# Title: President Trump - Meet the Press... "No I will not do any executive orders to limit abortion"
# URL: https://debatepolitics.com/threads/president-trump-meet-the-press-no-i-will-not-do-any-executive-orders-to-limit-abortion.556927/
# Replies: 72
# Views: 938
# --------------------------------------------------
# Title: Trumps fake campaign promises are falling like dominoes or cut like a drug dealer's cocaine. Election fraud is consequential & criminal.
# URL: https://debatepolitics.com/threads/trumps-fake-campaign-promises-are-falling-like-dominoes-or-cut-like-a-drug-dealers-cocaine-election-fraud-is-consequential-criminal.557303/
# Replies: 36
# Views: 587
# --------------------------------------------------
# Title: TRUMP RENEGES ON THE USMCA - HIS OWN ADMINISTRATION'S TRADE AGREEMENT NEGOTIATED & SIGNED IN 2020
# URL: https://debatepolitics.com/threads/trump-reneges-on-the-usmca-his-own-administrations-trade-agreement-negotiated-signed-in-2020.557839/
# Replies: 12
# Views: 298
# --------------------------------------------------
# Title: Trump's inaugural fund receives $1 million donation from Mark Zuckerberg's Meta
# URL: https://debatepolitics.com/threads/trumps-inaugural-fund-receives-1-million-donation-from-mark-zuckerbergs-meta.557111/
# Replies: 54
# Views: 533
# --------------------------------------------------
# Title: Now It’s Panama’s Turn In the Barrel
# URL: https://debatepolitics.com/threads/now-it%E2%80%99s-panama%E2%80%99s-turn-in-the-barrel.557723/
# Replies: 133
# Views: 2K
# --------------------------------------------------
# Title: You know its very hard. LOL
# URL: https://debatepolitics.com/threads/you-know-its-very-hard-lol.557147/
# Replies: 281
# Views: 2K
# --------------------------------------------------
# Title: Western Kentucky Professor: Trump's victory signals that human decency is no longer an American virtue
# URL: https://debatepolitics.com/threads/western-kentucky-professor-trumps-victory-signals-that-human-decency-is-no-longer-an-american-virtue.556543/
# Replies: 363
# Views: 3K
# --------------------------------------------------
# Title: Fetterman slams legal cases against Trump, Hunter Biden in first Truth Social post: ‘Cases were both bulls—‘
# URL: https://debatepolitics.com/threads/fetterman-slams-legal-cases-against-trump-hunter-biden-in-first-truth-social-post-%E2%80%98cases-were-both-bulls%E2%80%94%E2%80%98.557112/
# Replies: 85
# Views: 876
# --------------------------------------------------
# Title: Chip Roy On the Outside?
# URL: https://debatepolitics.com/threads/chip-roy-on-the-outside.557584/
# Replies: 29
# Views: 332
# --------------------------------------------------
# Title: This Cannot Be a Possibility, Wut?
# URL: https://debatepolitics.com/threads/this-cannot-be-a-possibility-wut.557551/
# Replies: 81
# Views: 750
# --------------------------------------------------
# Title: How long will President Musk tolerate Trump interference ?
# URL: https://debatepolitics.com/threads/how-long-will-president-musk-tolerate-trump-interference.557564/
# Replies: 53
# Views: 535
# --------------------------------------------------
# Title: RFK Jr.'s lawyer and top ally asked FDA to revoke approval of polio vaccine
# URL: https://debatepolitics.com/threads/rfk-jr-s-lawyer-and-top-ally-asked-fda-to-revoke-approval-of-polio-vaccine.557227/
# Replies: 32
# Views: 485
# --------------------------------------------------
# Title: Promises Made Promises Broken
# URL: https://debatepolitics.com/threads/promises-made-promises-broken.557136/
# Replies: 41
# Views: 455
# --------------------------------------------------

# %% [markdown]
# ### Putting All Together and Pagination

# %%
# import requests
# from bs4 import BeautifulSoup
import time  # To add delays between requests

# Base URL of the forum
BASE_URL = "https://debatepolitics.com"

# Start scraping from the first page
url = BASE_URL + "/forums/2024-us-presidential-election.227/"
all_data = []  # List to store all scraped data

while url:
    print(f"Scraping: {url}")  # Display current page being scraped
    
    # Add headers to avoid bot detection
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
    }

    # Fetch the webpage
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract Titles
    titles = [title.get_text(strip=True) for title in soup.select(".structItem-title a")]

    # Extract URLs (prepend with site domain)
    urls = [BASE_URL + link["href"] for link in soup.select(".structItem-title a")]

    # Extract Replies
    replies = [reply.get_text(strip=True) for reply in soup.select(".structItem-cell.structItem-cell--meta dl:nth-of-type(1) dd")]

    # Extract Views
    views = [view.get_text(strip=True) for view in soup.select(".structItem-cell.structItem-cell--meta dl:nth-of-type(2) dd")]

    # Store data in a list of dictionaries
    for i in range(len(titles)):
        all_data.append({
            "title": titles[i],
            "url": urls[i],
            "replies": replies[i],
            "views": views[i]
        })

    # Find "Next Page" button
    next_page = soup.select_one(".pageNav .pageNav-jump--next")

    if next_page:
        next_url = next_page["href"]
        url = BASE_URL + next_url  # Append the base URL
        time.sleep(2)  # Add a short delay to avoid overloading the server
    else:
        break  # No more pages, stop the loop

# Print collected data
for post in all_data[:5]:  # Print first 5 posts as a preview
    print(post)
# Out:
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-2
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-3
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-4
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-5
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-6
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-7
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-8
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-9
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-10
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-11
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-12
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-13
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-14
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-15
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-16
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-17
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-18
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-19
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-20
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-21
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-22
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-23
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-24
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-25
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-26
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-27
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-28
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-29
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-30
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-31
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-32
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-33
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-34
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-35
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-36
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-37
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-38
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-39
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-40
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-41
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-42
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-43
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-44
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-45
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-46
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-47
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-48
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-49
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-50
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-51
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-52
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-53
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-54
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-55
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-56
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-57
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-58
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-59
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-60
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-61
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-62
# Scraping: https://debatepolitics.com/forums/2024-us-presidential-election.227/page-63
# {'title': 'For some Latinos, ‘prosperity gospel’ led them to Trump', 'url': 'https://debatepolitics.com/threads/for-some-latinos-%E2%80%98prosperity-gospel%E2%80%99-led-them-to-trump.557926/', 'replies': '48', 'views': '2K'}
# {'title': 'How the GOP is on Self-Destruct', 'url': 'https://debatepolitics.com/threads/how-the-gop-is-on-self-destruct.557954/', 'replies': '2', 'views': '174'}
# {'title': "Kamala's Been On A Drinking Binge Since Losing", 'url': 'https://debatepolitics.com/threads/kamalas-been-on-a-drinking-binge-since-losing.556181/', 'replies': '187', 'views': '2K'}
# {'title': 'The Victory', 'url': 'https://debatepolitics.com/threads/the-victory.554963/', 'replies': '182', 'views': '2K'}
# {'title': 'It Must Really Suck For You People', 'url': 'https://debatepolitics.com/threads/it-must-really-suck-for-you-people.557448/', 'replies': '290', 'views': '2K'}

# %% [markdown]
# ### Save Data to CSV

# %%
import pandas as pd

# Save data to CSV
df = pd.DataFrame(all_data)
df.to_csv("/Users/kaiyang/Desktop/debatepolitics_posts_full.csv", index=False)

print("Data saved to debatepolitics_forum_posts.csv")
# Out:
# Data saved to debatepolitics_forum_posts.csv
